# %%
import pandas as pd

# %%
df = pd.read_csv('final_data_no_ref.csv')

# %%
len(df.columns)
# Out:
# 107

# %%
df.dtypes
# Out:
# loan_type_credit card               bool
# loan_type_mortgage                  bool
# loan_type_personal                  bool
# loan_purpose_Home Improvement       bool
# loan_purpose_Home Purchase          bool
#                                   ...
# num_delinquencies_2yrs           float64
# num_inquiries_6mo                  int64
# num_collections                    int64
# account_diversity_index          float64
# default                            int64
# Length: 107, dtype: object
