# %%
import pandas as pd

# %%
df = pd.read_csv('final_no_missing2.csv')

# %%
df['account_open_year'] = df['account_open_year'].transform(str)

# %%
df = df.drop(['num_login_sessions', 'num_customer_service_calls', 'has_mobile_app', 'paperless_billing'], axis=1)

# %%
df['loan_type'].value_counts()
# Out:
# loan_type
# personal       35892
# mortgage       23367
# credit card    22118
# Home Loan       7790
# Name: count, dtype: int64

# %%
numeric_columns = df.select_dtypes(exclude='object')
object_columns = df.select_dtypes(include='object')

# %%
object_columns
# Out:
#          loan_type        loan_purpose origination_channel marketing_campaign  \
# 0         personal  Debt Consolidation         Direct Mail                  W
# 1         mortgage           Refinance              Branch                  B
# 2         personal      Major Purchase              Online                  K
# 3         personal             Medical              Online                  A
# 4         personal  Debt Consolidation              Branch                  S
# ...            ...                 ...                 ...                ...
# 89162     personal    Home Improvement              Branch                  O
# 89163     personal               Other              Branch                  D
# 89164     personal      Major Purchase              Online                  J
# 89165  credit card    Revolving Credit              Branch                  K
# 89166     mortgage           Refinance              Online                  J
#
# ...

# %%
df[['account_open_year', 'default']]
# Out:
#       account_open_year  default
# 0                  2013        0
# 1                  2015        1
# 2                  2020        0
# 3                  2010        0
# 4                  2020        0
# ...                 ...      ...
# 89162              2016        0
# 89163              2014        0
# 89164              2010        1
# 89165              2021        0
# 89166              2022        0
#
# [89167 rows x 2 columns]

# %%
numeric_columns = numeric_columns.drop(['application_hour', 'application_day_of_week'], axis=1)

# %%
# numeric_columns = numeric_columns.drop(['num_customer_service_calls', 'has_mobile_app', 'paperless_billing'], axis=1)

# %%
numeric_columns
# Out:
#        loan_amount  loan_term  interest_rate  loan_to_value_ratio  \
# 0            17700         36          12.50                0.000
# 1           114000        180           6.83                0.774
# 2             9300         36          13.99                0.000
# 3             8700         48          13.26                0.000
# 4             7200         24          10.77                0.000
# ...            ...        ...            ...                  ...
# 89162        11300         24           9.70                0.000
# 89163        16500         36          11.67                0.000
# 89164        17800         36          14.99                0.000
# 89165        11700          0          19.10                0.000
# 89166       487100        360           5.03                0.894
#
#        loan_officer_id  monthly_income  existing_monthly_debt  \
# 0                 1045         5150.00                 738.64
# ...

# %%
object_columns
# Out:
#          loan_type        loan_purpose origination_channel marketing_campaign  \
# 0         personal  Debt Consolidation         Direct Mail                  W
# 1         mortgage           Refinance              Branch                  B
# 2         personal      Major Purchase              Online                  K
# 3         personal             Medical              Online                  A
# 4         personal  Debt Consolidation              Branch                  S
# ...            ...                 ...                 ...                ...
# 89162     personal    Home Improvement              Branch                  O
# 89163     personal               Other              Branch                  D
# 89164     personal      Major Purchase              Online                  J
# 89165  credit card    Revolving Credit              Branch                  K
# 89166     mortgage           Refinance              Online                  J
#
# ...

# %%
object_columns['referral_code'].value_counts()
# Out:
# referral_code
# REF0000    71326
# REF4315       13
# REF4048        9
# REF9450        9
# REF1887        8
#            ...
# REF6142        1
# REF1378        1
# REF6969        1
# REF2345        1
# REF3820        1
# Name: count, Length: 7773, dtype: int64

# %%
numeric_columns = df.select_dtypes(exclude='object')
object_columns = df.select_dtypes(include='object')

# %%
object_columns
# Out:
#          loan_type        loan_purpose origination_channel marketing_campaign  \
# 0         personal  Debt Consolidation         Direct Mail                  W
# 1         mortgage           Refinance              Branch                  B
# 2         personal      Major Purchase              Online                  K
# 3         personal             Medical              Online                  A
# 4         personal  Debt Consolidation              Branch                  S
# ...            ...                 ...                 ...                ...
# 89162     personal    Home Improvement              Branch                  O
# 89163     personal               Other              Branch                  D
# 89164     personal      Major Purchase              Online                  J
# 89165  credit card    Revolving Credit              Branch                  K
# 89166     mortgage           Refinance              Online                  J
#
# ...

# %%
object_columns = object_columns.drop('account_open_year', axis=1)

# %%
object_columns
# Out:
#          loan_type        loan_purpose origination_channel marketing_campaign  \
# 0         personal  Debt Consolidation         Direct Mail                  W
# 1         mortgage           Refinance              Branch                  B
# 2         personal      Major Purchase              Online                  K
# 3         personal             Medical              Online                  A
# 4         personal  Debt Consolidation              Branch                  S
# ...            ...                 ...                 ...                ...
# 89162     personal    Home Improvement              Branch                  O
# 89163     personal               Other              Branch                  D
# 89164     personal      Major Purchase              Online                  J
# 89165  credit card    Revolving Credit              Branch                  K
# 89166     mortgage           Refinance              Online                  J
#
# ...

# %%
objects_num_column = pd.get_dummies(object_columns, drop_first=True)

# %%
objects_num_column
# Out:
#        loan_type_credit card  loan_type_mortgage  loan_type_personal  \
# 0                      False               False                True
# 1                      False                True               False
# 2                      False               False                True
# 3                      False               False                True
# 4                      False               False                True
# ...                      ...                 ...                 ...
# 89162                  False               False                True
# 89163                  False               False                True
# 89164                  False               False                True
# 89165                   True               False               False
# 89166                  False                True               False
#
#        loan_purpose_Home Improvement  loan_purpose_Home Purchase  \
# 0                              False                       False
# ...

# %%
new_df = pd.concat([objects_num_column, numeric_columns], axis=1)

# %%
new_df
# Out:
#        loan_type_credit card  loan_type_mortgage  loan_type_personal  \
# 0                      False               False                True
# 1                      False                True               False
# 2                      False               False                True
# 3                      False               False                True
# 4                      False               False                True
# ...                      ...                 ...                 ...
# 89162                  False               False                True
# 89163                  False               False                True
# 89164                  False               False                True
# 89165                   True               False               False
# 89166                  False                True               False
#
#        loan_purpose_Home Improvement  loan_purpose_Home Purchase  \
# 0                              False                       False
# ...

# %%
len(new_df.columns)
# Out:
# 7880

# %%
df.to_csv('final_dataset.csv', index=False)

# %%
new_df.to_csv('final_dataset_to_train.csv', index=False)

# %%
df = df.drop(['cust_id', 'application_hour', 'application_day_of_week', 'account_open_year'], axis=1)

# %%
df
# Out:
#          loan_type  loan_amount  loan_term  interest_rate        loan_purpose  \
# 0         personal        17700         36          12.50  Debt Consolidation
# 1         mortgage       114000        180           6.83           Refinance
# 2         personal         9300         36          13.99      Major Purchase
# 3         personal         8700         48          13.26             Medical
# 4         personal         7200         24          10.77  Debt Consolidation
# ...            ...          ...        ...            ...                 ...
# 89162     personal        11300         24           9.70    Home Improvement
# 89163     personal        16500         36          11.67               Other
# 89164     personal        17800         36          14.99      Major Purchase
# 89165  credit card        11700          0          19.10    Revolving Credit
# 89166     mortgage       487100        360           5.03           Refinance
#
# ...

# %%
numeric_columns = df.select_dtypes(exclude='object')
object_columns = df.select_dtypes(include='object')

# %%
objects_num_column = pd.get_dummies(object_columns, drop_first=True)

# %%
new_df = pd.concat([objects_num_column, numeric_columns], axis=1)
# Out:
#          loan_type        loan_purpose origination_channel marketing_campaign  \
# 0         personal  Debt Consolidation         Direct Mail                  W
# 1         mortgage           Refinance              Branch                  B
# 2         personal      Major Purchase              Online                  K
# 3         personal             Medical              Online                  A
# 4         personal  Debt Consolidation              Branch                  S
# ...            ...                 ...                 ...                ...
# 89162     personal    Home Improvement              Branch                  O
# 89163     personal               Other              Branch                  D
# 89164     personal      Major Purchase              Online                  J
# 89165  credit card    Revolving Credit              Branch                  K
# 89166     mortgage           Refinance              Online                  J
#
# ...

# %%
objects_num_column
# Out:
#        loan_type_credit card  loan_type_mortgage  loan_type_personal  \
# 0                      False               False                True
# 1                      False                True               False
# 2                      False               False                True
# 3                      False               False                True
# 4                      False               False                True
# ...                      ...                 ...                 ...
# 89162                  False               False                True
# 89163                  False               False                True
# 89164                  False               False                True
# 89165                   True               False               False
# 89166                  False                True               False
#
#        loan_purpose_Home Improvement  loan_purpose_Home Purchase  \
# 0                              False                       False
# ...

# %%
numeric_columns
# Out:
#        loan_amount  loan_term  interest_rate  loan_to_value_ratio  \
# 0            17700         36          12.50                0.000
# 1           114000        180           6.83                0.774
# 2             9300         36          13.99                0.000
# 3             8700         48          13.26                0.000
# 4             7200         24          10.77                0.000
# ...            ...        ...            ...                  ...
# 89162        11300         24           9.70                0.000
# 89163        16500         36          11.67                0.000
# 89164        17800         36          14.99                0.000
# 89165        11700          0          19.10                0.000
# 89166       487100        360           5.03                0.894
#
#        loan_officer_id  monthly_income  existing_monthly_debt  \
# 0                 1045         5150.00                 738.64
# ...

# %%
columns = object_columns.columns

# %%
len(columns)
# Out:
# 11

# %%
for col in columns:
    print(f"{col} {len(object_columns[col].value_counts())}")
# Out:
# loan_type 4
# loan_purpose 8
# origination_channel 4
# marketing_campaign 26
# employment_type 4
# education 5
# marital_status 3
# state 20
# preferred_contact 3
# referral_code 7773
# account_status_code 5

# %%
object_columns['referral_code'].value_counts()
# Out:
# referral_code
# REF0000    71326
# REF4315       13
# REF4048        9
# REF9450        9
# REF1887        8
#            ...
# REF6142        1
# REF1378        1
# REF6969        1
# REF2345        1
# REF3820        1
# Name: count, Length: 7773, dtype: int64

# %%
object_columns['referral_code', ]

# %%
df[['referral_code', 'default']]
# Out:
#       referral_code  default
# 0           REF0000        0
# 1           REF0000        1
# 2           REF0000        0
# 3           REF0000        0
# 4           REF0000        0
# ...             ...      ...
# 89162       REF0000        0
# 89163       REF9754        0
# 89164       REF0000        1
# 89165       REF0000        0
# 89166       REF0000        0
#
# [89167 rows x 2 columns]

# %%
numeric_columns = df.select_dtypes(exclude='object')
object_columns = df.select_dtypes(include='object')

# %%
new_df = pd.concat([objects_num_column, numeric_columns], axis=1)

# %%
new_df
# Out:
#        loan_type_credit card  loan_type_mortgage  loan_type_personal  \
# 0                      False               False                True
# 1                      False                True               False
# 2                      False               False                True
# 3                      False               False                True
# 4                      False               False                True
# ...                      ...                 ...                 ...
# 89162                  False               False                True
# 89163                  False               False                True
# 89164                  False               False                True
# 89165                   True               False               False
# 89166                  False                True               False
#
#        loan_purpose_Home Improvement  loan_purpose_Home Purchase  \
# 0                              False                       False
# ...

# %%
df
# Out:
#          loan_type  loan_amount  loan_term  interest_rate        loan_purpose  \
# 0         personal        17700         36          12.50  Debt Consolidation
# 1         mortgage       114000        180           6.83           Refinance
# 2         personal         9300         36          13.99      Major Purchase
# 3         personal         8700         48          13.26             Medical
# 4         personal         7200         24          10.77  Debt Consolidation
# ...            ...          ...        ...            ...                 ...
# 89162     personal        11300         24           9.70    Home Improvement
# 89163     personal        16500         36          11.67               Other
# 89164     personal        17800         36          14.99      Major Purchase
# 89165  credit card        11700          0          19.10    Revolving Credit
# 89166     mortgage       487100        360           5.03           Refinance
#
# ...

# %%
(df[df['referral_code']=='REF0000']['default']).value_counts()
# Out:
# default
# 0    67704
# 1     3622
# Name: count, dtype: int64

# %%
df['default'].value_counts()
# Out:
# default
# 0    84611
# 1     4556
# Name: count, dtype: int64

# %%
df2 = df.drop('referral_code', axis=1)

# %%
df2
# Out:
#          loan_type  loan_amount  loan_term  interest_rate        loan_purpose  \
# 0         personal        17700         36          12.50  Debt Consolidation
# 1         mortgage       114000        180           6.83           Refinance
# 2         personal         9300         36          13.99      Major Purchase
# 3         personal         8700         48          13.26             Medical
# 4         personal         7200         24          10.77  Debt Consolidation
# ...            ...          ...        ...            ...                 ...
# 89162     personal        11300         24           9.70    Home Improvement
# 89163     personal        16500         36          11.67               Other
# 89164     personal        17800         36          14.99      Major Purchase
# 89165  credit card        11700          0          19.10    Revolving Credit
# 89166     mortgage       487100        360           5.03           Refinance
#
# ...

# %%
numeric_columns2 = df2.select_dtypes(exclude='object')
object_columns2 = df2.select_dtypes(include='object')

# %%
object_columns2
# Out:
#          loan_type        loan_purpose origination_channel marketing_campaign  \
# 0         personal  Debt Consolidation         Direct Mail                  W
# 1         mortgage           Refinance              Branch                  B
# 2         personal      Major Purchase              Online                  K
# 3         personal             Medical              Online                  A
# 4         personal  Debt Consolidation              Branch                  S
# ...            ...                 ...                 ...                ...
# 89162     personal    Home Improvement              Branch                  O
# 89163     personal               Other              Branch                  D
# 89164     personal      Major Purchase              Online                  J
# 89165  credit card    Revolving Credit              Branch                  K
# 89166     mortgage           Refinance              Online                  J
#
# ...

# %%
objects_num_column2 = pd.get_dummies(object_columns2, drop_first=True)

# %%
objects_num_column2
# Out:
#        loan_type_credit card  loan_type_mortgage  loan_type_personal  \
# 0                      False               False                True
# 1                      False                True               False
# 2                      False               False                True
# 3                      False               False                True
# 4                      False               False                True
# ...                      ...                 ...                 ...
# 89162                  False               False                True
# 89163                  False               False                True
# 89164                  False               False                True
# 89165                   True               False               False
# 89166                  False                True               False
#
#        loan_purpose_Home Improvement  loan_purpose_Home Purchase  \
# 0                              False                       False
# ...

# %%
new_df2 = pd.concat([objects_num_column2, numeric_columns2], axis=1)

# %%
new_df2.to_csv('final_data_no_ref.csv', index=False)

# %%
df.to_csv('final_df_with_ref.csv', index=False)

# %%
numeric_columns = df.select_dtypes(exclude='object')
object_columns = df.select_dtypes(include='object')

# %%
df2.to_csv('final_df_without_ref.csv', index=False)

# %%
objects_num_column = pd.get_dummies(object_columns, drop_first=True)

# %%
new_df = pd.concat([objects_num_column, numeric_columns], axis=1)

# %%
new_df.to_csv('final_dataset_with_ref.csv', index=False)
