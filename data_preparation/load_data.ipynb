# %%
import pandas as pd

# %%
load_df = pd.read_csv('merged.csv')

# %%
load_df.isnull().sum()
# Out:
# customer_id                   0
# loan_type                     0
# loan_amount                   0
# loan_term                     0
# interest_rate                 0
#                              ..
# num_login_sessions            0
# num_customer_service_calls    0
# has_mobile_app                0
# paperless_billing             0
# default                       0
# Length: 68, dtype: int64
