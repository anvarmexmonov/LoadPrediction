# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
merged_df = pd.read_csv('merged.csv')

# %%
merged_df.describe()
# Out:
#         customer_id     loan_term  interest_rate  loan_to_value_ratio  \
# count  89999.000000  89999.000000   89999.000000         89999.000000
# mean   54999.000000    132.369204      11.278835             0.273598
# std    25980.617776    152.657187       4.607331             0.378284
# min    10000.000000      0.000000       2.500000             0.000000
# 25%    32499.500000     12.000000       6.960000             0.000000
# 50%    54999.000000     48.000000      11.290000             0.000000
# 75%    77498.500000    360.000000      14.820000             0.725000
# max    99998.000000    360.000000      22.800000             0.970000
#
#        loan_officer_id      cust_num  debt_to_income_ratio  \
# count     89999.000000  89999.000000          89999.000000
# mean       1045.791587  54999.000000              0.531225
# std          32.327924  25980.617776              0.379553
# min         995.000000  10000.000000              0.054000
# ...

# %%
def percent_missing(df):
    percent_nan = 100*df.isnull().sum()/len(df)
    percent_nan = percent_nan[percent_nan > 0].sort_values(ascending=False)
    return percent_nan

# %%
percent_missing(merged_df)
# Out:
# employment_length         2.503361
# revolving_balance         1.530017
# num_delinquencies_2yrs    0.924455
# dtype: float64

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89999 entries, 0 to 89998
# Data columns (total 68 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   customer_id                 89999 non-null  int64
#  1   loan_type                   89999 non-null  object
#  2   loan_amount                 89999 non-null  object
#  3   loan_term                   89999 non-null  int64
#  4   interest_rate               89999 non-null  float64
#  5   loan_purpose                89999 non-null  object
#  6   loan_to_value_ratio         89999 non-null  float64
#  7   origination_channel         89999 non-null  object
#  8   loan_officer_id             89999 non-null  int64
#  9   marketing_campaign          89999 non-null  object
#  10  cust_num                    89999 non-null  int64
#  11  monthly_income              89999 non-null  object
#  12  existing_monthly_debt       89999 non-null  object
# ...

# %%
merged_df['loan_type'].value_counts()
# Out:
# loan_type
# Personal         9097
# Personal Loan    9061
# personal         9050
# PERSONAL         9024
# Mortgage         7919
# Home Loan        7850
# MORTGAGE         7841
# mortgage         7819
# Credit Card      5698
# CreditCard       5659
# credit card      5497
# CC               5484
# Name: count, dtype: int64

# %%
# merged_df->cust_id, id, customer_number, customer_ref
# Out:
#        customer_id      loan_type loan_amount  loan_term  interest_rate  \
# 0            10000       Personal     $17,700         36          12.50
# 1            10001       mortgage    $114,000        180           6.83
# 2            10002  Personal Loan       9,300         36          13.99
# 3            10003       PERSONAL       $8700         48          13.26
# 4            10004       Personal      $7,200         24          10.77
# ...            ...            ...         ...        ...            ...
# 89994        99994       personal     $11,300         24           9.70
# 89995        99995       personal      16,500         36          11.67
# 89996        99996  Personal Loan      17,800         36          14.99
# 89997        99997    Credit Card      $11700          0          19.10
# 89998        99998       Mortgage     $487100        360           5.03
#
#              loan_purpose  loan_to_value_ratio origination_channel  \
# ...

# %%
# random_noise_1

# %%
merged_df['loan_type'].value_counts()
# Out:
# loan_type
# Personal         9097
# Personal Loan    9061
# personal         9050
# PERSONAL         9024
# Mortgage         7919
# Home Loan        7850
# MORTGAGE         7841
# mortgage         7819
# Credit Card      5698
# CreditCard       5659
# credit card      5497
# CC               5484
# Name: count, dtype: int64

# %%
merged_df['employment_type'].value_counts()
# Out:
# employment_type
# Full-time        12716
# Full Time        12692
# FULL_TIME        12608
# Fulltime         12582
# FT               12419
# SELF_EMPLOYED     3409
# Self Emp          3397
# Self Employed     3327
# Self-employed     3303
# PART_TIME         2296
# Part-time         2266
# PT                2247
# Part Time         2198
# Contractor        1560
# CONTRACT          1534
# Contract          1445
# Name: count, dtype: int64

# %%
merged_df['marital_status'].value_counts()
# Out:
# marital_status
# Married     51889
# Single      29806
# Divorced     8304
# Name: count, dtype: int64

# %%
merged_df
# Out:
#        customer_id      loan_type loan_amount  loan_term  interest_rate  \
# 0            10000       Personal     $17,700         36          12.50
# 1            10001       mortgage    $114,000        180           6.83
# 2            10002  Personal Loan       9,300         36          13.99
# 3            10003       PERSONAL       $8700         48          13.26
# 4            10004       Personal      $7,200         24          10.77
# ...            ...            ...         ...        ...            ...
# 89994        99994       personal     $11,300         24           9.70
# 89995        99995       personal      16,500         36          11.67
# 89996        99996  Personal Loan      17,800         36          14.99
# 89997        99997    Credit Card      $11700          0          19.10
# 89998        99998       Mortgage     $487100        360           5.03
#
#              loan_purpose  loan_to_value_ratio origination_channel  \
# ...

# %%
merged_df["loan_amount"] = merged_df['loan_amount'].replace({'\$': '', ',': ''}, regex=True)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# /tmp/ipykernel_6158/2043490230.py:1: SyntaxWarning: invalid escape sequence '\$'
#   merged_df["loan_amount"] = merged_df['loan_amount'].replace({'\$': '', ',': ''}, regex=True)

# %%
merged_df.columns
# Out:
# Index(['customer_id', 'loan_type', 'loan_amount', 'loan_term', 'interest_rate',
#        'loan_purpose', 'loan_to_value_ratio', 'origination_channel',
#        'loan_officer_id', 'marketing_campaign', 'cust_num', 'monthly_income',
#        'existing_monthly_debt', 'monthly_payment', 'debt_to_income_ratio',
#        'debt_service_ratio', 'payment_to_income_ratio', 'credit_utilization',
#        'revolving_balance', 'credit_usage_amount', 'available_credit',
#        'total_monthly_debt_payment', 'annual_debt_payment',
#        'loan_to_annual_income', 'total_debt_amount', 'monthly_free_cash_flow',
#        'cust_id', 'age', 'annual_income', 'employment_length',
#        'employment_type', 'education', 'marital_status', 'num_dependents',
#        'id', 'state', 'regional_unemployment_rate', 'regional_median_income',
#        'regional_median_rent', 'housing_price_index', 'cost_of_living_index',
#        'previous_zip_code', 'customer_number', 'credit_score',
# ...

# %%
merged_df
# Out:
#        customer_id      loan_type loan_amount  loan_term  interest_rate  \
# 0            10000       Personal       17700         36          12.50
# 1            10001       mortgage      114000        180           6.83
# 2            10002  Personal Loan        9300         36          13.99
# 3            10003       PERSONAL        8700         48          13.26
# 4            10004       Personal        7200         24          10.77
# ...            ...            ...         ...        ...            ...
# 89994        99994       personal       11300         24           9.70
# 89995        99995       personal       16500         36          11.67
# 89996        99996  Personal Loan       17800         36          14.99
# 89997        99997    Credit Card       11700          0          19.10
# 89998        99998       Mortgage      487100        360           5.03
#
#              loan_purpose  loan_to_value_ratio origination_channel  \
# ...

# %%
merged_df['interest_rate']
# Out:
# 0        12.50
# 1         6.83
# 2        13.99
# 3        13.26
# 4        10.77
#          ...
# 89994     9.70
# 89995    11.67
# 89996    14.99
# 89997    19.10
# 89998     5.03
# Name: interest_rate, Length: 89999, dtype: float64

# %%
merged_df['loan_officer_id']
# Out:
# 0        1045
# 1        1011
# 2        1084
# 3        1048
# 4        1055
#          ...
# 89994    1050
# 89995    1071
# 89996    1046
# 89997     997
# 89998    1003
# Name: loan_officer_id, Length: 89999, dtype: int64

# %%
merged_df = merged_df.drop('cust_num', axis=1)

# %%
merged_df['monthly_income'] = (
    merged_df['monthly_income']
    .str.replace(r'[\$,]', '', regex=True) # Use .str.replace on string series
    .astype(float)
)

# %%
merged_df['monthly_income']
# Out:
# 0        5150.00
# 1        2383.33
# 2        1725.00
# 3        2616.67
# 4        2050.00
#           ...
# 89994    6025.00
# 89995    1666.67
# 89996    1666.67
# 89997    1666.67
# 89998    2133.33
# Name: monthly_income, Length: 89999, dtype: float64

# %%
sample = merged_df['existing_monthly_debt']

# %%
merged_df['existing_monthly_debt'] = (
    merged_df['existing_monthly_debt']
    .str.replace(r'[\$,]', '', regex=True) # Use .str.replace on string series
    .astype(float)
)

# %%
merged_df['existing_monthly_debt']
# Out:
# 0         738.64
# 1         392.21
# 2         204.07
# 3         288.71
# 4         248.77
#           ...
# 89994    2120.97
# 89995     138.97
# 89996     129.90
# 89997     162.11
# 89998     303.19
# Name: existing_monthly_debt, Length: 89999, dtype: float64

# %%
sample
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 sample
#
# NameError: name 'sample' is not defined

# %%
sample = merged_df['monthly_payment']

# %%
merged_df['monthly_payment'] = (
    merged_df['monthly_payment']
    .str.replace(r'[\$,]', '', regex=True) # Use .str.replace on string series
    .astype(float)
)

# %%
sample
# Out:
# 0         $592.13
# 1        1,013.86
# 2         $317.81
# 3          234.52
# 4          334.81
#            ...
# 89994      519.87
# 89995     $545.44
# 89996      616.96
# 89997     $351.00
# 89998    2,623.80
# Name: monthly_payment, Length: 89999, dtype: object

# %%
merged_df['monthly_payment']
# Out:
# 0         592.13
# 1        1013.86
# 2         317.81
# 3         234.52
# 4         334.81
#           ...
# 89994     519.87
# 89995     545.44
# 89996     616.96
# 89997     351.00
# 89998    2623.80
# Name: monthly_payment, Length: 89999, dtype: float64

# %%
merged_df
# Out:
#        customer_id      loan_type loan_amount  loan_term  interest_rate  \
# 0            10000       Personal       17700         36          12.50
# 1            10001       mortgage      114000        180           6.83
# 2            10002  Personal Loan        9300         36          13.99
# 3            10003       PERSONAL        8700         48          13.26
# 4            10004       Personal        7200         24          10.77
# ...            ...            ...         ...        ...            ...
# 89994        99994       personal       11300         24           9.70
# 89995        99995       personal       16500         36          11.67
# 89996        99996  Personal Loan       17800         36          14.99
# 89997        99997    Credit Card       11700          0          19.10
# 89998        99998       Mortgage      487100        360           5.03
#
#              loan_purpose  loan_to_value_ratio origination_channel  \
# ...

# %%
merged_df[[
    'credit_usage_amount',
    'available_credit',
    'total_monthly_debt_payment',
    'total_debt_amount',
    'monthly_free_cash_flow',
    'annual_income',
]]
# Out:
#       credit_usage_amount available_credit total_monthly_debt_payment  \
# 0             $142,213.10       $26,886.90                    1330.77
# 1               75,932.20        $2,267.80                    1406.07
# 2               22,314.60       $19,085.40                     521.88
# 3                  8820.0        51,180.00                     523.23
# 4                 24253.6        25,446.40                     583.58
# ...                   ...              ...                        ...
# 89994           48,680.40       $86,919.60                   2,640.84
# 89995             15833.0       $28,767.00                    $684.41
# 89996             12242.7        $6,057.30                    $746.86
# 89997           30,516.60          23783.4                     513.11
# 89998              5877.6        17,822.40                   2,926.99
#
#       total_debt_amount monthly_free_cash_flow annual_income
# 0            159,913.10               3,819.23        $61800
# ...

# %%
financial_cols = [
    'credit_usage_amount',
    'available_credit',
    'total_monthly_debt_payment',
    'total_debt_amount',
    'monthly_free_cash_flow',
    'annual_income',
]

for col in financial_cols:
    merged_df[col] = (
        merged_df[col]
        .astype(str) # Ensure it's treated as a string series first
        .str.replace(r'[\$,]', '', regex=True)
        .astype(float)
    )

# %%
merged_df
# Out:
#        customer_id      loan_type loan_amount  loan_term  interest_rate  \
# 0            10000       Personal       17700         36          12.50
# 1            10001       mortgage      114000        180           6.83
# 2            10002  Personal Loan        9300         36          13.99
# 3            10003       PERSONAL        8700         48          13.26
# 4            10004       Personal        7200         24          10.77
# ...            ...            ...         ...        ...            ...
# 89994        99994       personal       11300         24           9.70
# 89995        99995       personal       16500         36          11.67
# 89996        99996  Personal Loan       17800         36          14.99
# 89997        99997    Credit Card       11700          0          19.10
# 89998        99998       Mortgage      487100        360           5.03
#
#              loan_purpose  loan_to_value_ratio origination_channel  \
# ...

# %%
def convert_loan_type(value):
  if value in ['Personal', 'Personal Loan', 'personal', 'PERSONAL']:
    return 'personal'
  elif value in ['MORTGAGE', 'mortgage', 'Mortgage']:
    return 'mortgage'
  elif value in ['Credit Card', 'CreditCard', 'credit card', 'CC']:
    return 'credit card'
  else:
    return value

merged_df['loan_type'] = merged_df['loan_type'].map(convert_loan_type)


def convert_employment_type(value):
  if value in ['Full-time', 'Full Time', 'FULL_TIME', 'Fulltime', 'FT']:
    return 'Full-time'
  elif value in ['SELF_EMPLOYED', 'Self Emp', 'Self Employed', 'Self-employed']:
    return 'Self-employed'
  elif value in ['PART_TIME', 'Part-time', 'Part Time', 'PT']:
    return 'Part-time'
  elif value in ['Contractor', 'CONTRACT', 'Contract']:
    return 'Contract'

merged_df['employment_type'] = merged_df['employment_type'].apply(convert_employment_type)

# %%
merged_df=merged_df.drop('customer_number', axis=1)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89999 entries, 0 to 89998
# Data columns (total 66 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   customer_id                 89999 non-null  int64
#  1   loan_type                   89999 non-null  object
#  2   loan_amount                 89999 non-null  object
#  3   loan_term                   89999 non-null  int64
#  4   interest_rate               89999 non-null  float64
#  5   loan_purpose                89999 non-null  object
#  6   loan_to_value_ratio         89999 non-null  float64
#  7   origination_channel         89999 non-null  object
#  8   loan_officer_id             89999 non-null  int64
#  9   marketing_campaign          89999 non-null  object
#  10  monthly_income              89999 non-null  float64
#  11  existing_monthly_debt       89999 non-null  float64
#  12  monthly_payment             89999 non-null  float64
# ...

# %%
merged_df[['debt_to_income_ratio','debt_service_ratio']]
# Out:
#        debt_to_income_ratio  debt_service_ratio
# 0                     0.258            0.258402
# 1                     0.590            0.589959
# 2                     0.303            0.302539
# 3                     0.200            0.199961
# 4                     0.285            0.284673
# ...                     ...                 ...
# 89994                 0.438            0.438314
# 89995                 0.411            0.410646
# 89996                 0.448            0.448116
# 89997                 0.308            0.307866
# 89998                 1.372            1.372027
#
# [89999 rows x 2 columns]

# %%
merged_df = merged_df.drop('customer_ref', axis=1)

# %%
merged_df=merged_df.drop('application_id',axis=1)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89999 entries, 0 to 89998
# Data columns (total 64 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   customer_id                 89999 non-null  int64
#  1   loan_type                   89999 non-null  object
#  2   loan_amount                 89999 non-null  object
#  3   loan_term                   89999 non-null  int64
#  4   interest_rate               89999 non-null  float64
#  5   loan_purpose                89999 non-null  object
#  6   loan_to_value_ratio         89999 non-null  float64
#  7   origination_channel         89999 non-null  object
#  8   loan_officer_id             89999 non-null  int64
#  9   marketing_campaign          89999 non-null  object
#  10  monthly_income              89999 non-null  float64
#  11  existing_monthly_debt       89999 non-null  float64
#  12  monthly_payment             89999 non-null  float64
# ...

# %%
merged_df[['customer_id','credit_usage_amount','revolving_balance']]
# Out:
#        customer_id  credit_usage_amount revolving_balance
# 0            10000             142213.1       $142,213.10
# 1            10001              75932.2        $75,932.20
# 2            10002              22314.6           22314.6
# 3            10003               8820.0          8,820.00
# 4            10004              24253.6           24253.6
# ...            ...                  ...               ...
# 89994        99994              48680.4         48,680.40
# 89995        99995              15833.0         15,833.00
# 89996        99996              12242.7         12,242.70
# 89997        99997              30516.6        $30,516.60
# 89998        99998               5877.6            5877.6
#
# [89999 rows x 3 columns]

# %%
merged_df['revolving_balance'] = (
    merged_df['revolving_balance']
    .str.replace(r'[\$,]', '', regex=True) # Use .str.replace on string series
    .astype(float)
)

# %%
merged_df
# Out:
#        customer_id    loan_type loan_amount  loan_term  interest_rate  \
# 0            10000     personal       17700         36          12.50
# 1            10001     mortgage      114000        180           6.83
# 2            10002     personal        9300         36          13.99
# 3            10003     personal        8700         48          13.26
# 4            10004     personal        7200         24          10.77
# ...            ...          ...         ...        ...            ...
# 89994        99994     personal       11300         24           9.70
# 89995        99995     personal       16500         36          11.67
# 89996        99996     personal       17800         36          14.99
# 89997        99997  credit card       11700          0          19.10
# 89998        99998     Mortgage      487100        360           5.03
#
#              loan_purpose  loan_to_value_ratio origination_channel  \
# ...

# %%
merged_df.to_csv('merged_changed_different.csv', index=False)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89999 entries, 0 to 89998
# Data columns (total 62 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   customer_id                 89999 non-null  int64
#  1   loan_type                   89999 non-null  object
#  2   loan_amount                 89999 non-null  object
#  3   loan_term                   89999 non-null  int64
#  4   interest_rate               89999 non-null  float64
#  5   loan_purpose                89999 non-null  object
#  6   loan_to_value_ratio         89999 non-null  float64
#  7   origination_channel         89999 non-null  object
#  8   loan_officer_id             89999 non-null  int64
#  9   marketing_campaign          89999 non-null  object
#  10  monthly_income              89999 non-null  float64
#  11  existing_monthly_debt       89999 non-null  float64
#  12  monthly_payment             89999 non-null  float64
# ...

# %%
merged_df[[
    'num_delinquencies_2yrs',
    'num_inquiries_6mo',
    'num_public_records',
    'num_collections',
    'recent_inquiry_count']]
# Out:
#        num_delinquencies_2yrs  num_inquiries_6mo  num_public_records  \
# 0                         0.0                  2                   1
# 1                         0.0                  6                   0
# 2                         0.0                  2                   0
# 3                         0.0                  1                   0
# 4                         0.0                  1                   0
# ...                       ...                ...                 ...
# 89994                     0.0                  1                   0
# 89995                     0.0                  1                   0
# 89996                     0.0                  2                   1
# 89997                     0.0                  3                   0
# 89998                     0.0                  5                   0
#
#        num_collections  recent_inquiry_count
# 0                    0                     2
# 1                    0                     6
# ...

# %%
merged_df[['num_inquiries_6mo', 'recent_inquiry_count']]
# Out:
#        num_inquiries_6mo  recent_inquiry_count
# 0                      2                     2
# 1                      6                     6
# 2                      2                     2
# 3                      1                     1
# 4                      1                     1
# ...                  ...                   ...
# 89994                  1                     1
# 89995                  1                     1
# 89996                  2                     2
# 89997                  3                     3
# 89998                  5                     5
#
# [89999 rows x 2 columns]

# %%
merged_df[['annual_income', 'monthly_income']]
# Out:
#        annual_income  monthly_income
# 0            61800.0         5150.00
# 1            28600.0         2383.33
# 2            20700.0         1725.00
# 3            31400.0         2616.67
# 4            24600.0         2050.00
# ...              ...             ...
# 89994        72300.0         6025.00
# 89995        20000.0         1666.67
# 89996        20000.0         1666.67
# 89997        20000.0         1666.67
# 89998        25600.0         2133.33
#
# [89999 rows x 2 columns]

# %%
yillik = merged_df['monthly_income']*12

# %%
yillik
# Out:
# 0        61800.00
# 1        28599.96
# 2        20700.00
# 3        31400.04
# 4        24600.00
#            ...
# 89994    72300.00
# 89995    20000.04
# 89996    20000.04
# 89997    20000.04
# 89998    25599.96
# Name: monthly_income, Length: 89999, dtype: float64

# %%
merged_df['annual_income']
# Out:
# 0        61800.0
# 1        28600.0
# 2        20700.0
# 3        31400.0
# 4        24600.0
#           ...
# 89994    72300.0
# 89995    20000.0
# 89996    20000.0
# 89997    20000.0
# 89998    25600.0
# Name: annual_income, Length: 89999, dtype: float64

# %%
merged_df
# Out:
#        customer_id    loan_type loan_amount  loan_term  interest_rate  \
# 0            10000     personal       17700         36          12.50
# 1            10001     mortgage      114000        180           6.83
# 2            10002     personal        9300         36          13.99
# 3            10003     personal        8700         48          13.26
# 4            10004     personal        7200         24          10.77
# ...            ...          ...         ...        ...            ...
# 89994        99994     personal       11300         24           9.70
# 89995        99995     personal       16500         36          11.67
# 89996        99996     personal       17800         36          14.99
# 89997        99997  credit card       11700          0          19.10
# 89998        99998     Mortgage      487100        360           5.03
#
#              loan_purpose  loan_to_value_ratio origination_channel  \
# ...

# %%
merged_df.isnull().sum()
# Out:
# customer_id                   0
# loan_type                     0
# loan_amount                   0
# loan_term                     0
# interest_rate                 0
#                              ..
# num_login_sessions            0
# num_customer_service_calls    0
# has_mobile_app                0
# paperless_billing             0
# default                       0
# Length: 64, dtype: int64

# %%
merged_df
# Out:
#        customer_id    loan_type loan_amount  loan_term  interest_rate  \
# 0            10000     personal       17700         36          12.50
# 1            10001     mortgage      114000        180           6.83
# 2            10002     personal        9300         36          13.99
# 3            10003     personal        8700         48          13.26
# 4            10004     personal        7200         24          10.77
# ...            ...          ...         ...        ...            ...
# 89994        99994     personal       11300         24           9.70
# 89995        99995     personal       16500         36          11.67
# 89996        99996     personal       17800         36          14.99
# 89997        99997  credit card       11700          0          19.10
# 89998        99998     Mortgage      487100        360           5.03
#
#              loan_purpose  loan_to_value_ratio origination_channel  \
# ...

# %%
merged_df
# Out:
#        customer_id    loan_type loan_amount  loan_term  interest_rate  \
# 0            10000     personal       17700         36          12.50
# 1            10001     mortgage      114000        180           6.83
# 2            10002     personal        9300         36          13.99
# 3            10003     personal        8700         48          13.26
# 4            10004     personal        7200         24          10.77
# ...            ...          ...         ...        ...            ...
# 89994        99994     personal       11300         24           9.70
# 89995        99995     personal       16500         36          11.67
# 89996        99996     personal       17800         36          14.99
# 89997        99997  credit card       11700          0          19.10
# 89998        99998     Mortgage      487100        360           5.03
#
#              loan_purpose  loan_to_value_ratio origination_channel  \
# ...

# %%
merged_df.to_csv('changes_and_with_dup.csv', index=False)

# %%
new_df = merged_df

# %%
new_df = new_df.drop(['annual_income', 'recent_inquiry_count', 'random_noise_1', 'revolving_balance', 'debt_to_income_ratio'], axis=1)

# %%
new_df
# Out:
#        customer_id    loan_type loan_amount  loan_term  interest_rate  \
# 0            10000     personal       17700         36          12.50
# 1            10001     mortgage      114000        180           6.83
# 2            10002     personal        9300         36          13.99
# 3            10003     personal        8700         48          13.26
# 4            10004     personal        7200         24          10.77
# ...            ...          ...         ...        ...            ...
# 89994        99994     personal       11300         24           9.70
# 89995        99995     personal       16500         36          11.67
# 89996        99996     personal       17800         36          14.99
# 89997        99997  credit card       11700          0          19.10
# 89998        99998     Mortgage      487100        360           5.03
#
#              loan_purpose  loan_to_value_ratio origination_channel  \
# ...

# %%
new_df.to_csv('changes_and_without_dup.csv', index=False)
